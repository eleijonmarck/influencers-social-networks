# %%
import pandas as pd

import json

# %%
train = pd.read_csv('train.csv')

# %%
train.columns
# Out:
# Index([u'Choice', u'A_follower_count', u'A_following_count', u'A_listed_count',
#        u'A_mentions_received', u'A_retweets_received', u'A_mentions_sent',
#        u'A_retweets_sent', u'A_posts', u'A_network_feature_1',
#        u'A_network_feature_2', u'A_network_feature_3', u'B_follower_count',
#        u'B_following_count', u'B_listed_count', u'B_mentions_received',
#        u'B_retweets_received', u'B_mentions_sent', u'B_retweets_sent',
#        u'B_posts', u'B_network_feature_1', u'B_network_feature_2',
#        u'B_network_feature_3'],
#       dtype='object')

# %%
train.head()
# Out:
#    Choice  A_follower_count  A_following_count  A_listed_count  \
# 0       0               228                302               3
# 1       0             21591               1179             228
# 2       0              7310               1215             101
# 3       0                20                  7               2
# 4       1             45589                862            2641
#
#    A_mentions_received  A_retweets_received  A_mentions_sent  A_retweets_sent  \
# 0             0.583979             0.100503         0.100503         0.100503
# 1            90.456506            25.798292         5.709329         1.111159
# 2            25.503644             9.556347         5.361519         0.591206
# 3             7.690824             0.277306         1.331508         0.100503
# 4           148.854279            36.998884        27.881768         3.333492
#
#      A_posts  A_network_feature_1         ...           B_following_count  \
# ...

# %%
train.Choice.value_counts()
# Out:
# 1    2802
# 0    2698
# Name: Choice, dtype: int64
